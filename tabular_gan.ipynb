# %% [markdown]
# # CTGAN Model For Tabular Data

# %%
# !pip install sdv

# %%
import warnings; warnings.simplefilter('ignore')
import pandas as pd
from sdv.tabular import CTGAN
from sdv.evaluation import evaluate
from sdv.constraints import *

# %% [markdown]
# ### Import dataset here...

# %%
data_path = './credit_merge_clean.csv'

# %%
real_data = pd.read_csv(data_path)
print("DATA SHAPE:", real_data.shape)
# Out:
# DATA SHAPE: (36457, 21)

# %%
real_data.head()
# Out:
#    Unnamed: 0       ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0           0  5008804           M            Y               Y             0
# 1           1  5008805           M            Y               Y             0
# 2           2  5008806           M            Y               Y             0
# 3           3  5008808           F            N               Y             0
# 4           4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  ... DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0        Civil marriage  ...     -12005          -4542           1
# 1        Civil marriage  ...     -12005          -4542           1
# 2               Married  ...     -21474          -1134           1
# 3  Single / not married  ...     -19110          -3051           1
# 4  Single / not married  ...     -19110          -3051           1
#
#    FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE CNT_FAM_MEMBERS  \
# 0                1           0           0              NaN             2.0
# 1                1           0           0              NaN             2.0
# 2                0           0           0   Security staff             2.0
# 3                0           1           1      Sales staff             1.0
# 4                0           1           1      Sales staff             1.0
#
#    begin_month  target
# 0        -15.0       1
# 1        -14.0       1
# 2        -29.0       0
# 3         -4.0       0
# 4        -26.0       0
#
# [5 rows x 21 columns]

# %%
real_data = real_data.drop(['Unnamed: 0'], axis=1)
real_data = real_data.dropna() 
print(real_data.shape)
# Out:
# (25134, 20)

# %%
real_data
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 2      5008806           M            Y               Y             0
# 3      5008808           F            N               Y             0
# 4      5008809           F            N               Y             0
# 5      5008810           F            N               Y             0
# 6      5008811           F            N               Y             0
# ...        ...         ...          ...             ...           ...
# 36452  5149828           M            Y               Y             0
# 36453  5149834           F            N               Y             0
# 36454  5149838           F            N               Y             0
# 36455  5150049           F            N               Y             0
# 36456  5150337           M            N               Y             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 2              112500.0               Working  Secondary / secondary special
# 3              270000.0  Commercial associate  Secondary / secondary special
# 4              270000.0  Commercial associate  Secondary / secondary special
# 5              270000.0  Commercial associate  Secondary / secondary special
# 6              270000.0  Commercial associate  Secondary / secondary special
# ...                 ...                   ...                            ...
# 36452          315000.0               Working  Secondary / secondary special
# 36453          157500.0  Commercial associate               Higher education
# 36454          157500.0             Pensioner               Higher education
# 36455          283500.0               Working  Secondary / secondary special
# 36456          112500.0               Working  Secondary / secondary special
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 2                   Married  House / apartment      -21474          -1134
# 3      Single / not married  House / apartment      -19110          -3051
# 4      Single / not married  House / apartment      -19110          -3051
# 5      Single / not married  House / apartment      -19110          -3051
# 6      Single / not married  House / apartment      -19110          -3051
# ...                     ...                ...         ...            ...
# 36452               Married  House / apartment      -17348          -2420
# 36453               Married  House / apartment      -12387          -1325
# 36454               Married  House / apartment      -12387          -1325
# 36455               Married  House / apartment      -17958           -655
# 36456  Single / not married   Rented apartment       -9188          -1193
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 2               1                0           0           0  Security staff
# 3               1                0           1           1     Sales staff
# 4               1                0           1           1     Sales staff
# 5               1                0           1           1     Sales staff
# 6               1                0           1           1     Sales staff
# ...           ...              ...         ...         ...             ...
# 36452           1                0           0           0        Managers
# 36453           1                0           1           1  Medicine staff
# 36454           1                0           1           1  Medicine staff
# 36455           1                0           0           0     Sales staff
# 36456           1                0           0           0        Laborers
#
#        CNT_FAM_MEMBERS  begin_month  target
# 2                  2.0        -29.0       0
# 3                  1.0         -4.0       0
# 4                  1.0        -26.0       0
# 5                  1.0        -26.0       0
# 6                  1.0        -38.0       0
# ...                ...          ...     ...
# 36452              2.0        -11.0       1
# 36453              2.0        -23.0       1
# 36454              2.0        -32.0       1
# 36455              2.0         -9.0       1
# 36456              1.0        -13.0       1
#
# [25134 rows x 20 columns]

# %% [markdown]
# Going to create 2 GAN models:
# * One that emulates the complete the original data using the complete real datase;
# * Another one from the real data, but spcifically with target value 1 (positive mortgage default), for balancing dataset puposes.

# %% [markdown]
# ## 1 - GAN model using complete dataset...

# %%
# https://pypi.org/project/sdv/
# https://sdv.dev/SDV/user_guides/single_table/handling_constraints.html#load-a-tabular-demo

####################
# Constraints List #
####################

# days_birth greater than 21 yrs - 7665 days
age_lt_7665 = GreaterThan(
    low='DAYS_BIRTH',
    high=-7300,
    scalar='high',
    handling_strategy='reject_sampling'
)

# days_employed smaller than days_birth
days_birth_gt_days_employed = GreaterThan(
    low='DAYS_BIRTH',
    high='DAYS_EMPLOYED',
    handling_strategy='reject_sampling')

# days_birth, months_balance always negative
always_negative_no_zero = Negative(
    columns='DAYS_BIRTH',
    strict=False,
    handling_strategy='reject_sampling'
)
always_negative_with_zero = Negative(
    columns='begin_month',
    strict=True,  # includes zero
    handling_strategy='reject_sampling'
)

# If Days_Employed > 0: unemployed is pensioner
def NAME_INCOME_TYPE(data):
    return data['DAYS_EMPLOYED'] > 0
    
name_income_type_pensioner = ColumnFormula(
   column='NAME_INCOME_TYPE',
   formula=NAME_INCOME_TYPE,
   handling_strategy='transform'
)

constraints = [
    age_lt_7665,
    days_birth_gt_days_employed,
    always_negative_no_zero,
#     always_negative_with_zero,
#     name_income_type_pensioner
]

# %%
complete_ctgan = CTGAN(
#     epochs = 5,
    constraints=constraints,
#     cuda = True
)

# %%
complete_ctgan.fit(real_data)

# %%
# Generate N number of samples
synthetic_all_data = complete_ctgan.sample(num_rows=20000)

# %%
synthetic_all_data
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5144135           M            Y               N             0
# 1      5068349           M            Y               Y             0
# 2      5026434           F            N               Y             0
# 3      5031188           M            Y               Y             1
# 4      5114643           M            Y               Y             1
# ...        ...         ...          ...             ...           ...
# 19995  5009530           M            N               N             0
# 19996  5046422           M            N               N             0
# 19997  5050208           F            N               Y             0
# 19998  5091480           F            N               N             0
# 19999  5127984           F            Y               N             1
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0              159787.7               Working  Secondary / secondary special
# 1              305604.7  Commercial associate  Secondary / secondary special
# 2              143568.7         State servant  Secondary / secondary special
# 3              123765.0               Working  Secondary / secondary special
# 4              342192.3  Commercial associate               Higher education
# ...                 ...                   ...                            ...
# 19995          135375.9  Commercial associate               Higher education
# 19996          108572.5               Working  Secondary / secondary special
# 19997          160162.1               Working  Secondary / secondary special
# 19998          162075.5               Working               Higher education
# 19999          272316.7               Working  Secondary / secondary special
#
#       NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0                Married       With parents      -15297           -981
# 1                Married   Rented apartment      -17361          -1076
# 2                Married  House / apartment      -10395          -3425
# 3              Separated   Rented apartment      -10569           -216
# 4                Married  House / apartment      -12266           -801
# ...                  ...                ...         ...            ...
# 19995          Separated  House / apartment      -11976          -1300
# 19996            Married   Rented apartment      -12997          -3369
# 19997              Widow  House / apartment      -21226          -5334
# 19998            Married  House / apartment      -13878          -3284
# 19999            Married  House / apartment       -9803          -1791
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0               1                0           0           0  Security staff
# 1               1                0           0           0        Laborers
# 2               1                0           1           0     Sales staff
# 3               1                0           0           0        Laborers
# 4               1                0           0           1     Accountants
# ...           ...              ...         ...         ...             ...
# 19995           1                1           1           1         Drivers
# 19996           1                0           0           0        Laborers
# 19997           1                1           0           0  Medicine staff
# 19998           1                1           0           0     Accountants
# 19999           1                0           0           0        Laborers
#
#        CNT_FAM_MEMBERS  begin_month  target
# 0                  2.0        -24.0       0
# 1                  2.0        -19.0       0
# 2                  2.0        -13.0       0
# 3                  1.0        -19.0       1
# 4                  3.0        -23.0       1
# ...                ...          ...     ...
# 19995              2.0        -21.0       0
# 19996              2.0        -38.0       0
# 19997              2.0        -12.0       1
# 19998              2.0        -47.0       0
# 19999              3.0        -22.0       0
#
# [20000 rows x 20 columns]

# %% [markdown]
# Evaluate synthetic data created...

# %%
# 0 the worst and 1 the best possible score
evaluate(synthetic_all_data, real_data)
# Out:
# 0.7127094189411184

# %% [markdown]
# Save model and data...

# %%
# save data on csv format
synthetic_all_data.to_csv('synthetic_all_data.csv')

# save model
complete_ctgan.save('gan_model_complete_default.pkl')

# %% [markdown]
# ## 2 - GAN Model considering on default mortage individuals only...

# %%
real_data['target'].value_counts()
# Out:
# 0    22045
# 1     3089
# Name: target, dtype: int64

# %%
# create dataset with only default mortgage individuals
on_default_data = real_data[real_data['target'] == 1]

# %%
on_default_data.head()
# Out:
#          ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 18  5008825           F            Y               N             0
# 19  5008826           F            Y               N             0
# 20  5008830           F            N               Y             0
# 21  5008831           F            N               Y             0
# 22  5008832           F            N               Y             0
#
#     AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 18          130500.0          Working              Incomplete higher
# 19          130500.0          Working              Incomplete higher
# 20          157500.0          Working  Secondary / secondary special
# 21          157500.0          Working  Secondary / secondary special
# 22          157500.0          Working  Secondary / secondary special
#
#    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 18            Married  House / apartment      -10669          -1103
# 19            Married  House / apartment      -10669          -1103
# 20            Married  House / apartment      -10031          -1469
# 21            Married  House / apartment      -10031          -1469
# 22            Married  House / apartment      -10031          -1469
#
#     FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 18           1                0           0           0     Accountants
# 19           1                0           0           0     Accountants
# 20           1                0           1           0        Laborers
# 21           1                0           1           0        Laborers
# 22           1                0           1           0        Laborers
#
#     CNT_FAM_MEMBERS  begin_month  target
# 18              2.0        -25.0       1
# 19              2.0        -30.0       1
# 20              2.0        -31.0       1
# 21              2.0        -19.0       1
# 22              2.0        -34.0       1

# %%
def_ctgan = CTGAN(
#     epochs = 5,
    constraints=constraints,
#     cuda = True
)

# %%
def_ctgan.fit(on_default_data)

# %%
# Generate N number of samples
synthetic_on_default_data = def_ctgan.sample(num_rows=15000)

# %%
synthetic_on_default_data
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5065193           M            Y               Y             0
# 1      5087936           F            Y               Y             1
# 2      5106025           M            N               Y             0
# 3      5044945           F            N               N             1
# 4      5111347           F            Y               Y             1
# ...        ...         ...          ...             ...           ...
# 14995  5058756           M            Y               Y             1
# 14996  5027978           M            Y               Y             1
# 14997  5060237           F            Y               Y             0
# 14998  5012790           F            Y               N             0
# 14999  5108055           M            Y               Y             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0              162472.5               Working               Higher education
# 1              190337.7               Working              Incomplete higher
# 2              153333.4               Working  Secondary / secondary special
# 3              231938.0         State servant  Secondary / secondary special
# 4              376239.5  Commercial associate               Higher education
# ...                 ...                   ...                            ...
# 14995          367135.9               Working               Higher education
# 14996          226358.8               Working              Incomplete higher
# 14997          435857.5               Working  Secondary / secondary special
# 14998          238882.8               Working               Higher education
# 14999          212511.4  Commercial associate  Secondary / secondary special
#
#          NAME_FAMILY_STATUS    NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0                   Married    House / apartment      -12242         -11213
# 1                   Married    House / apartment      -19262           -606
# 2                   Married    House / apartment      -15296          -5478
# 3      Single / not married    House / apartment      -16471          -1223
# 4                   Married  Municipal apartment      -18415           -697
# ...                     ...                  ...         ...            ...
# 14995               Married    House / apartment       -8374          -1301
# 14996             Separated    House / apartment       -8677          -1367
# 14997               Married    House / apartment      -18796          -2588
# 14998  Single / not married     Rented apartment      -15810          -2435
# 14999  Single / not married    House / apartment      -10086          -1213
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  \
# 0               1                1           0           1
# 1               1                1           0           0
# 2               1                0           1           0
# 3               1                0           0           0
# 4               1                0           0           0
# ...           ...              ...         ...         ...
# 14995           1                0           0           0
# 14996           1                0           0           0
# 14997           1                1           0           0
# 14998           1                0           0           0
# 14999           1                0           0           1
#
#              OCCUPATION_TYPE  CNT_FAM_MEMBERS  begin_month  target
# 0                   Laborers              2.0        -18.0       1
# 1                   Laborers              2.0        -28.0       1
# 2                   Laborers              2.0         -2.0       1
# 3                   Laborers              1.0         -2.0       1
# 4                Accountants              2.0         -5.0       1
# ...                      ...              ...          ...     ...
# 14995  High skill tech staff              3.0         -1.0       1
# 14996               Laborers              2.0        -44.0       1
# 14997          Cooking staff              2.0        -41.0       1
# 14998            Accountants              1.0         -8.0       1
# 14999                Drivers              2.0        -52.0       1
#
# [15000 rows x 20 columns]

# %% [markdown]
# Evaluate model...

# %%
# 0 the worst and 1 the best possible score
evaluate(synthetic_on_default_data, on_default_data)
# Out:
# 0.6357171170999111

# %% [markdown]
# Save model and data...

# %%
# save data on csv format
synthetic_on_default_data.to_csv('on_default_mortgage_individuals_data.csv')

# save model
def_ctgan.save('gan_model_on_default_mortgage_individuals.pkl')
